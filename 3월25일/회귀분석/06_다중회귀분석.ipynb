# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import font_manager, rc
import platform
plt.rc('font', family = 'Malgun Gothic')

# 선형회귀분석 모듈
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# 다항식으로 변환하는 모듈(2차원으로 변환해서 사용)
from sklearn.preprocessing import PolynomialFeatures

# %%
df = pd.read_csv("./file_new/auto-mpg_v2.csv")
ndf = df[['연비','실린더','배기량','중량']]

# %%
x = ndf[["실린더", "배기량", "중량"]]
y = ndf["연비"]

# %%
# train 80%, test 30%로 구분하여 조회
x_train, x_test, y_train, y_test = train_test_split(x,
                                                    y,
                                                    test_size = 0.3,
                                                    random_state = 10)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)
# Out:
# 0.6776497480623118

# %%
y_hat = lr.predict(x_test)
y_hat
# Out:
# array([27.66392591, 27.74192358, 18.68030295, 32.38142015, 14.63560166,
#        20.34500065, 15.91351868,  8.18060683, 29.01047009, 29.25670418,
#        20.90781153, 20.35053944, 26.66884898, 27.31634285, 13.39167899,
#        17.05553183, 23.60690999, 29.58234859, 12.95782902, 12.54453747,
#        13.52113103, 31.01684693, 22.0513803 , 14.66295595, 16.76433612,
#        11.01697222, 18.3246232 , 30.14201145, 21.38620554, 25.08928863,
#        21.5977248 , 21.70547601, 27.21663588, 22.97261835, 22.63593313,
#        30.49030651, 31.04219125, 19.82812102, 16.39449169, 26.79488686,
#        21.69967109, 23.24188388, 30.22908521, 23.62737505, 24.13225143,
#        11.16471528, 14.50622317, 31.69545327, 22.14251513, 29.82642125,
#        29.38737216, 12.08557253, 22.73636057, 13.65965503, 16.18558821,
#        23.88232011, 23.42373162, 29.83590644, 31.16045951, 26.5915633 ,
#        30.85742049, 27.62483863, 19.8106821 , 23.24377918, 26.89611269,
#        32.34275892,  9.01071005, 24.47481099, 23.47246402, 14.22971178,
#        12.88251654, 29.20912679, 26.38755603, 30.66445403, 29.73892991,
#        25.80236063, 21.24449675, 13.73048886, 31.21960148, 30.99560046,
#        31.15460933, 12.34853767, 27.00978349, 12.77635773, 17.39752649,
#        27.87471621, 18.99957342, 20.94844595, 25.60472731, 29.25753933,
#        30.19609584, 14.91507285, 31.3208273 , 30.66445403, 12.89245608,
#        29.03782438, 27.04449832, 13.7242296 , 19.35122169, 30.17471631,
#        31.03156802, 28.00610467, 29.96464648, 22.43109071, 25.43970833,
#        28.85715146, 31.29278931, 13.4464287 , 29.4422039 , 11.37539939,
#        10.92052794, 20.19380666, 22.31590541, 31.15460933, 26.98060745,
#        15.37210572, 28.40269759, 19.29317251])

# %%
plt.figure(figsize = (10,5))
ax1 = sns.kdeplot(y, label="y")
ax2 = sns.kdeplot(y_hat, label="y_hat", ax=ax1)

plt.legend()
plt.show()
